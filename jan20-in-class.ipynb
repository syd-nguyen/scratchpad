# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('../data/iowa.csv', encoding='latin1')
df.head()
# Out:
#   Invoice/Item Number        Date  Store Number                   Store Name  \
# 0     INV-59108400026  06/06/2023          3723           J D SPIRITS LIQUOR
# 1        S16879800057  01/16/2014          3926  LIQUOR DOWNTOWN / IOWA CITY
# 2     INV-05301100019  06/05/2017          3829     GARY'S FOODS / MT VERNON
# 3     INV-40973500083  10/14/2021          5102               WILKIE LIQUORS
# 4     INV-17022500013  01/18/2019          2560   HY-VEE FOOD STORE / MARION
#
#   Zip Code          Category Name           Vendor Name  Item Number  \
# 0    51040  STRAIGHT RYE WHISKIES      INFINIUM SPIRITS        27102
# 1    52240         VODKA 80 PROOF    HEAVEN HILL BRANDS        35416
# 2    52314      CANADIAN WHISKIES       DIAGEO AMERICAS        11296
# 3    52314      AMERICAN SCHNAPPS       JIM BEAM BRANDS        82787
# 4    52302        WHISKEY LIQUEUR  SAZERAC COMPANY  INC        64863
#
#             Item Description  Bottle Volume (ml)  State Bottle Cost  \
# ...

# %% [markdown]
# ## Looking at `Category Name`

# %%
df['Category Name'].unique()
# no nans :)
# Out:
# array(['STRAIGHT RYE WHISKIES', 'VODKA 80 PROOF', 'CANADIAN WHISKIES',
#        'AMERICAN SCHNAPPS', 'WHISKEY LIQUEUR', 'IRISH WHISKIES',
#        'PUERTO RICO & VIRGIN ISLANDS RUM', 'AMERICAN BRANDIES',
#        'SPICED RUM', 'TENNESSEE WHISKIES', 'TEQUILA',
#        'IMPORTED FLAVORED VODKA', 'AMERICAN FLAVORED VODKA',
#        'COCKTAILS/RTD', 'AMERICAN VODKAS', 'MIXTO TEQUILA',
#        '100% AGAVE TEQUILA', 'MISC. AMERICAN CORDIALS & LIQUEURS',
#        'ANISETTE', 'IMPORTED VODKAS', 'IMPORTED SCHNAPPS', 'FLAVORED RUM',
#        'PEPPERMINT SCHNAPPS', 'STRAIGHT BOURBON WHISKIES', 'BARBADOS RUM',
#        'MISC. IMPORTED CORDIALS & LIQUEURS', 'IMPORTED BRANDIES',
#        'CREAM LIQUEURS', 'BLENDED WHISKIES', 'AMERICAN DRY GINS',
#        'AMERICAN CORDIALS & LIQUEURS', 'IMPORTED CORDIALS & LIQUEURS',
#        'NEUTRAL GRAIN SPIRITS FLAVORED', 'AMERICAN GRAPE BRANDIES',
#        'TRIPLE SEC', 'SCOTCH WHISKIES', 'BLACKBERRY BRANDIES',
# ...

# %%
sns.catplot(df, kind='count', x='Category Name', aspect=5)
plt.xticks(rotation=90)
plt.show()
